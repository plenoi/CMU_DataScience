# %% [markdown]
# ## Question 1
# Please use Numpy to generate matrix of size (5,5) containing 88 and all diagonal element is set to 0. Then, replicate this matrix 2 times in vertical direction.

# %%
# Out:
# array([[ 0., 88., 88., 88., 88.],
#        [88.,  0., 88., 88., 88.],
#        [88., 88.,  0., 88., 88.],
#        [88., 88., 88.,  0., 88.],
#        [88., 88., 88., 88.,  0.],
#        [ 0., 88., 88., 88., 88.],
#        [88.,  0., 88., 88., 88.],
#        [88., 88.,  0., 88., 88.],
#        [88., 88., 88.,  0., 88.],
#        [88., 88., 88., 88.,  0.]])

# %% [markdown]
# ## Question 2
# Go to Yahoo Finance -> Type NOBLE.BK -> Historical Data -> Download Data. <br> You will get NOBLE.BK.csv. Create the graph to see the trend of NOBLE during 2019-01 to 2019-02 using Exponential Moving Average (EMA, 10, 25, 50 days)

# %% [markdown]
# ## Question 3
# Load adult dataset from <br>
# https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data <br>
# perform preprocessing to change this dataset into normalized (0 to 1) numerical data with 2 class (0 <=50k, 1 >50k) <br>
# <b>Note: feature selection is not required<b>

# %% [markdown]
# ## Question 4
# Load breast cancer dataset from scikit dataset and visualize it as the follwing.

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
# 
plt.figure(figsize=(5,5),dpi=100)
#
# Out:
# Text(0.5, 1.0, 'PCA of Cancer dataset')
